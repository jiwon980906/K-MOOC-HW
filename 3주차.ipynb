# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
value = np.random.standard_normal(40)
value
# Out:
# array([-0.3627102 ,  0.35684268, -2.32782241, -1.07176438,  0.30706605,
#        -0.00712285, -0.2709386 , -0.47281507,  0.31016346, -0.39820181,
#         1.30619781,  0.61867387, -0.62698394, -1.09952816,  1.45114144,
#         0.75693339, -0.08149366, -0.72996839,  0.74264408, -0.09277079,
#         0.54402777, -0.52374801,  0.8762518 ,  1.48281276,  1.42427074,
#        -0.91718783, -1.87206594, -0.37235325, -0.07136203,  0.37277986,
#        -2.15998618,  0.97165633, -0.85468119,  2.94766436,  1.75786718,
#         2.0284737 ,  0.03919353, -0.14213168,  0.2670413 ,  0.17376692])

# %%
index = range(len(value))
plt.plot(index, value)
#x/y축 범위 설정
plt.xlim(0, 20)
plt.ylim(np.min(value)-1, np.max(value)+1)
# Out:
# (-3.3278224060516806, 3.9476643605468853)

# %%
plt.figure(figsize = (7, 4))
plt.plot(value.cumsum(), 'b', lw = 1.5)
plt.plot(value.cumsum(),'ro')
plt.xlabel('index')
plt.ylabel('value')
plt.title('Line Plot 1')
# Out:
# Text(0.5, 1.0, 'Line Plot 1')

# %%
value = np.random.standard_normal((30,2))
value
# Out:
# array([[ 0.8143334 ,  0.46432555],
#        [ 0.52187545,  1.39268742],
#        [-0.84061632, -1.30801178],
#        [ 1.01306716, -0.32633931],
#        [-0.71848466,  1.82776418],
#        [ 0.47453924, -1.20743768],
#        [ 0.20192805, -0.59463396],
#        [ 0.56290767,  0.57090691],
#        [-0.26633436, -0.02273972],
#        [ 0.10654794,  0.56217165],
#        [ 1.04112846, -1.74482407],
#        [-1.06664319, -1.85415201],
#        [ 0.72983431,  0.43016275],
#        [-0.42300974, -1.04295718],
#        [-0.76608784, -0.04881213],
#        [ 0.7616875 , -0.18612951],
#        [-2.45938204, -1.43973036],
#        [-1.31488734,  1.32739981],
#        [-0.27136995,  0.79323524],
#        [-0.02028338,  0.47930132],
#        [-0.16557701,  0.60772487],
#        [-0.31023221,  1.89310071],
#        [ 0.68993062,  1.54157188],
#        [-0.85868222, -0.5875665 ],
#        [ 0.34175514,  1.16616363],
#        [-0.12262166, -1.17447057],
#        [ 0.11766357,  1.65838056],
#        [-0.1380739 , -0.17098844],
#        [ 0.3948505 , -1.11850355],
#        [-1.17020054, -0.57626378]])

# %%
plt.figure(figsize = (10, 4))
plt.plot(value[:,0], lw = 1.5, label = '1st')
plt.plot(value[:,1], lw = 1.5, label = '2nd')
plt.plot(value,'ro')
plt.grid(True)
plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')
plt.title('Line Plot 2')
# Out:
# Text(0.5, 1.0, 'Line Plot 2')

# %%
#1번째
plt.figure(figsize = (10, 5))
plt.subplot(211)
plt.plot(value[:,0], lw = 1.5, label = '1st')
plt.plot(value[:,0],'ro')
plt.grid(True)
plt.legend(loc=0)
plt.ylabel("value")
plt.title('Line Plot 3')

#2번째
plt.subplot(212)
plt.plot(value[:,1], 'g', lw = 1.5, label = '2nd')
plt.plot(value[:,0],'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis("tight")
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
#1번째
plt.figure(figsize = (13, 5))
plt.subplot(231)
plt.plot(value[:,0], lw = 1.5, label = '1st')
plt.plot(value[:,0],'co')
plt.grid(True)
plt.legend(loc=0)
plt.ylabel("value")
plt.title('Line Plot 3')

#2번째
plt.subplot(232)
plt.plot(value[:,1], 'g', lw = 1.5, label = '1st')
plt.grid(True)
plt.legend(loc=0)
plt.axis("tight")
plt.ylabel('value')

#3번째
plt.subplot(233)
plt.plot(value[:,1], 'g', lw = 1.5, label = '1st')
plt.plot(value[:,0],'bD')
plt.grid(True)
plt.legend(loc=0)
plt.axis("tight")
plt.ylabel('value')

#4번째
plt.subplot(234)
plt.plot(value[:,1], 'g', lw = 1.5, label = '2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis("tight")
plt.ylabel('value')

#5번째
plt.subplot(235)
plt.plot(value[:,1], 'b', lw = 1.5, label = '2nd')
plt.plot(value[:,0],'ms')
plt.grid(True)
plt.legend(loc=0)
plt.axis("tight")
plt.ylabel('value')

#6번째
plt.subplot(236)
plt.plot(value[:,1], 'r--', lw = 1.5, label = '2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis("tight")
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
value = np.random.standard_normal((500,2))
plt.plot(value[:,0], value[:,1], 'ro')
plt.plot(False)
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 1')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 1')

# %%
plt.figure(figsize=(7,5))
plt.scatter(value[:,0], value[:,1], marker='o')
plt.grid(True)
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 2')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 2')

# %%
color = np.random.randint(0, 10, len(value))

plt.figure(figsize=(10,5))
plt.scatter(value[:,0], value[:,1], c=color, marker='o')
plt.colorbar()
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 3')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 3')

# %%
plt.figure(figsize=(12,7))
plt.hist(value, label = ['1st','2nd'], bins = 30)
plt.grid(True)
plt.legend(bbox_to_anchor = (1.2, 1), loc="upper right")
plt.xlabel('value')
plt.ylabel('freauency')
plt.title('Histogram 1')
# Out:
# Text(0.5, 1.0, 'Histogram 1')

# %%
plt.figure(figsize=(12,6))
plt.hist(value, label=['1st', '2nd'], bins = 30, color=('yellow', 'green'))
plt.grid(True)
plt.legend(bbox_to_anchor = (1.2, 1), loc="upper right")
plt.xlabel('value')
plt.ylabel('freauency')
plt.title('Histogram 2')
# Out:
# Text(0.5, 1.0, 'Histogram 2')

# %%
value = np.random.standard_normal(500)
cm = plt.cm.get_cmap('Spectral')
plt.figure(figsize=(12,6))

#plot histogram
n, bins, patches = plt.hist(value, bins = 30, color = 'green')
print("1. bins : " + str(bins))
print("2. the length of bins : " + str(len(bins)))
bin_centers = 0.5 * (bins[:-1] + bins[1:])
print("3. bin_centers : " + str(bin_centers))

#scale values to interval [0,1] : 정규화(normalization)
col = (bin_centers - min(bin_centers)) / (max(bin_centers) - min(bin_centers))
print("4. col : " + str(col))

for c, p in zip(col, patches):
    plt.setp(p, 'facecolor', cm(c))
    
    
plt.xlabel('value')
plt.ylabel('freauency')
plt.title('Histogram 3')
plt.show()
# Out:
# 1. bins : [-2.52311939 -2.34438834 -2.16565729 -1.98692624 -1.80819519 -1.62946414
#  -1.45073309 -1.27200204 -1.09327099 -0.91453994 -0.73580889 -0.55707784
#  -0.37834679 -0.19961574 -0.02088469  0.15784636  0.33657741  0.51530846
#   0.69403951  0.87277056  1.05150161  1.23023266  1.4089637   1.58769475
#   1.7664258   1.94515685  2.1238879   2.30261895  2.48135     2.66008105
#   2.8388121 ]
# 2. the length of bins : 31
# 3. bin_centers : [-2.43375386 -2.25502281 -2.07629176 -1.89756071 -1.71882966 -1.54009861
#  -1.36136756 -1.18263651 -1.00390546 -0.82517442 -0.64644337 -0.46771232
#  -0.28898127 -0.11025022  0.06848083  0.24721188  0.42594293  0.60467398
#   0.78340503  0.96213608  1.14086713  1.31959818  1.49832923  1.67706028
#   1.85579133  2.03452238  2.21325343  2.39198448  2.57071553  2.74944658]
# 4. col : [0.         0.03448276 0.06896552 0.10344828 0.13793103 0.17241379
#  0.20689655 0.24137931 0.27586207 0.31034483 0.34482759 0.37931034
#  0.4137931  0.44827586 0.48275862 0.51724138 0.55172414 0.5862069
#  0.62068966 0.65517241 0.68965517 0.72413793 0.75862069 0.79310345
#  0.82758621 0.86206897 0.89655172 0.93103448 0.96551724 1.        ]

# %%
import seaborn as sns
#set aesthetic parameters in one step
sns.set(style = 'whitegrid', palette = "pastel")

#Load the example tips dataset
data = sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(x="day", y="tip",hue="sex", data=data, palette = "muted")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
data2 = sns.load_dataset("flights")
data2
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
pivoted_data = data2.pivot("year", "month","passengers")
pivoted_data
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.set(context="poster", font="monospace")

sns.heatmap(pivoted_data, annot=True, fmt="d", linewidth=3)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.set()
sns.reset_orig()      #reset params to defaults
sns.heatmap(pivoted_data, annot=True, fmt="d", linewidth=3)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
import pandas as pd
from pandas import scatter_matrix
value = np.random.randn(500,4)
df = pd.DataFrame(value, columns = ['value 1','value 2', 'value 3', 'value 4'])
df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e4ca4eb17d29> in <module>
#       1 import pandas as pd
# ----> 2 from pandas import scatter_matrix
#       3 value = np.random.randn(500,4)
#       4 df = pd.DataFrame(value, columns = ['value 1','value 2', 'value 3', 'value 4'])
#       5 df
#
# ImportError: cannot import name 'scatter_matrix' from 'pandas' (C:\Users\ok\anaconda3\lib\site-packages\pandas\__init__.py)

# %%
scatter_matrix(df, alpha=0.2, figsize=(6,6), diagoal="hist")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-8fb4be58f894> in <module>
# ----> 1 scatter_matrix(df, alpha=0.2, figsize=(6,6), diagoal="hist")
#
# NameError: name 'scatter_matrix' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

 
x = np.arange(0, 100)
y = x * 2
z = x ** 2
plt.subplot(    211   )
plt.plot(x,y,color =   "blue"  ,   lw=  5)
plt.xlabel("X")
plt.ylabel("Y")
plt. title    ("First")
plt.subplot(   212    )
plt.plot(x,z,color="red",  lw   =3,  ls    ="--")
plt.xlabel("X")
plt.ylabel("Z")
plt.title("Second")
# Out:
# Text(0.5, 1.0, 'Second')
